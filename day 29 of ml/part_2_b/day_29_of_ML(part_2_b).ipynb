# %%
import pickle
import numpy as np

# %%
pipe = pickle.load(open('pipe.pkl','rb'))

# %%
import pandas as pd

test_input2 = pd.DataFrame({
    'Pclass': [2],
    'Sex': ['male'],
    'Age': [31.0],
    'SibSp': [0],
    'Parch': [0],
    'Fare': [10.5],
    'Embarked': ['S']
})

# %%
pipe.predict(test_input2)
# Out:
# array([0])
